# %% [markdown]
# Trabajo Practico Semanal N1

# %% [markdown]
# ![Screenshot from 2025-05-02 22-24-22.png](attachment:96ccb339-be43-49eb-a0b7-dea862746059.png)

# %% [markdown]
# Muestro el ejercicio hecho en manuscrito

# %%
from IPython.display import IFrame
IFrame("./TrabajoSemanal1_Sussini_Facundo.pdf", width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="./TrabajoSemanal1_Sussini_Facundo.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import numpy as np
from scipy import signal as sig

# PyTC2: La librería para TC2
from pytc2.sistemas_lineales import bodePlot, pzmap, GroupDelay, analyze_sys, pretty_print_lti

# %%
import matplotlib as mpl
from matplotlib import pyplot as plt
#%%  Inicialización de librerías

plt.figure(1)
plt.close(1)

#%% Esto tiene que ver con cuestiones de presentación de los gráficos,
fig_sz_x = 13
fig_sz_y = 7
fig_dpi = 80 # dpi
fig_font_size = 11

plt.rcParams.update({'font.size':fig_font_size})

# módulos numéricos y de funciones científicas
import numpy as np
from scipy import signal as sig

# Ahora importamos las funciones de PyTC2
from pytc2.sistemas_lineales import bodePlot, pzmap, GroupDelay, analyze_sys

from pytc2.general import print_subtitle
from pytc2.general import print_latex, a_equal_b_latex_s

# %%
#Parametros normalizados para DeltaW0=W0 y DeltaZ=R3
w0 = 1
c1 = 1
r3 = 1
r1 = 1
r2 = 1

#Cargamos la funcion trasnsferencia

num = np.array([1, -1])
den = np.array([1,  1])

H_normalizada = sig.TransferFunction( num, den)

display(H_normalizada)
# Out:
# TransferFunctionContinuous(
# array([ 1., -1.]),
# array([1., 1.]),
# dt: None
# )

# %% [raw]
# Transformo la trasnferencia normalizada a un formato que podamos entender

# %%
print_latex(a_equal_b_latex_s('H(s)', pretty_print_lti(num, den, displaystr=False)))
# Out:
# $\displaystyle H(s)=\frac{s +  -1 }{s +   1 }$

# %%
_, axes_hdl = bodePlot(H_normalizada)

plt.sca(axes_hdl[0])

pzmap(H_normalizada)

# La respuesta en Magnitud aparace asi por tema de Ruido, pero esta en escal de e-15 dB
# Out:
# (2, <Axes: xlabel='$\\sigma$', ylabel='j$\\omega$'>)

# %% [markdown]
# Simulacion en LTSpice

# %% [markdown]
# ![TP1.png](attachment:7381cc4a-78a4-477e-a112-3b5df2dd3f04.png)
