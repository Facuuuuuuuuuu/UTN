# %% [markdown]
# ![Tpl4.png](attachment:dde61ee8-1c18-4021-a44e-b2ec83a614a0.png)

# %%
from IPython.display import IFrame
IFrame("./TPL4_SussiniFacundo_Arreglado_V3.pdf", width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="./TPL4_SussiniFacundo_Arreglado_V3.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Módulos numéricos y de funciones científicas
import numpy as np
from scipy import signal as sig

# Ahora importamos las funciones de PyTC2
from pytc2.sistemas_lineales import bodePlot, pzmap, GroupDelay, analyze_sys, pretty_print_lti

from pytc2.general import print_subtitle
from pytc2.general import print_latex  

import matplotlib as mpl
from matplotlib import pyplot as plt

#%% Inicialización de librerías
plt.figure(1)
plt.close(1)

#%% Esto tiene que ver con cuestiones de presentación de los gráficos,
fig_sz_x = 13
fig_sz_y = 7
fig_dpi = 80 # dpi
fig_font_size = 11

plt.rcParams.update({'font.size':fig_font_size})



K=1
Q=0.7

f0=1000
w0= (2* np.pi * f0) * 1.4

num=np.array([-K])
den=np.array([1, 1/Q, 1])

H_normalizada = sig.TransferFunction(num, den)


_, axes_hdl = bodePlot(H_normalizada)

plt.sca(axes_hdl[0])

pzmap(H_normalizada)
# Out:
# (2, <Axes: xlabel='$\\sigma$', ylabel='j$\\omega$'>)

# %% [markdown]
# Simulacion De LTSpice

# %% [markdown]
# Se trata de un circuito Butterworth

# %% [markdown]
# ![CircuitoLTSpice.png](attachment:2dd5c067-a4e0-4ec4-9a9a-1cdc32fc4b15.png)

# %% [markdown]
# ![SimuLTSpice.png](attachment:d58d47a5-d833-421b-9b58-ef202568ad83.png)
